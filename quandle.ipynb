# %% [markdown]
# <a href="https://colab.research.google.com/github/pankaj18/time_series_forecasting/blob/master/quandle.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip3 install quandl

# %%
import quandl
data = quandl.get('NSE/OIL')

# %%
data
# Out:
#                Open     High  ...  Total Trade Quantity  Turnover (Lacs)
# Date                          ...
# 2009-09-30  1096.00  1156.70  ...            19748012.0        223877.07
# 2009-10-01  1102.00  1173.70  ...             3074254.0         35463.78
# 2009-10-05  1152.00  1165.90  ...              919832.0         10581.13
# 2009-10-06  1149.80  1157.20  ...              627957.0          7185.90
# 2009-10-07  1153.80  1160.70  ...              698216.0          8032.98
# ...             ...      ...  ...                   ...              ...
# 2018-12-31   178.10   179.00  ...              761462.0          1343.75
# 2019-01-01   175.00   176.40  ...              381570.0           669.16
# 2019-01-02   175.80   176.20  ...              722532.0          1251.85
# 2019-01-03   172.80   175.70  ...              698190.0          1212.34
# 2019-01-04   172.05   174.95  ...              431122.0           749.99
#
# [2299 rows x 7 columns]

# %%
data_sunspot=quandl.get('SIDC/SUNSPOTS_A')

# %%
data_sunspot
# Out:
#             Yearly Mean Total Sunspot Number  ...  Definitive/Provisional Indicator
# Date                                          ...
# 1700-12-31                               8.3  ...                               1.0
# 1701-12-31                              18.3  ...                               1.0
# 1702-12-31                              26.7  ...                               1.0
# 1703-12-31                              38.3  ...                               1.0
# 1704-12-31                              60.0  ...                               1.0
# ...                                      ...  ...                               ...
# 2015-12-31                              69.8  ...                               1.0
# 2016-12-31                              39.8  ...                               1.0
# 2017-12-31                              21.7  ...                               1.0
# 2018-12-31                               7.0  ...                               1.0
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.style.use('dark_background')

# %%
data_sunspot['Yearly Mean Total Sunspot Number'].plot(figsize=(15,6))

# %%
data_sunspot_daily=quandl.get('SIDC/SUNSPOTS_D')

# %%
data_sunspot_daily.head()
# Out:
#             Daily Sunspot Number  ...  Definitive/Provisional Indicator
# Date                              ...
# 1818-01-08                  65.0  ...                               1.0
# 1818-01-13                  37.0  ...                               1.0
# 1818-01-17                  77.0  ...                               1.0
# 1818-01-18                  98.0  ...                               1.0
# 1818-01-19                 105.0  ...                               1.0
#
# [5 rows x 4 columns]

# %%
data_sunspot_daily['Daily Sunspot Number'].plot(figsize=(15,6))

# %%
data_sunspot_monthly=quandl.get('SIDC/SUNSPOTS_M')

# %%
data_sunspot_monthly.head()
# Out:
#             Monthly Mean Total Sunspot Number  ...  Definitive/Provisional Indicator
# Date                                           ...
# 1749-01-31                               96.7  ...                               1.0
# 1749-02-28                              104.3  ...                               1.0
# 1749-03-31                              116.7  ...                               1.0
# 1749-04-30                               92.8  ...                               1.0
# 1749-05-31                              141.7  ...                               1.0
#
# [5 rows x 4 columns]

# %%
data_sunspot_monthly['Monthly Mean Total Sunspot Number'].plot(figsize=(15,6))
